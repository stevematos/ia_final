# %% [markdown]
# <h1><center>ANALISIS DE DATOS</center></h1>
# A continuacion interpretaremos los datos extraidos de la base de datos https://www.kaggle.com/roustekbio/breast-cancer-csv de manera empirica

# %%
import pandas as pd

# %%
datos = pd.read_csv('breast_cancer.csv')

# %% [markdown]
# # Visualizacion de datos

# %%
datos.head()
# Out:
#    espesor_del_grupo  uniformidad_del_tamano_de_celda  \
# 0                  5                                1
# 1                  5                                4
# 2                  3                                1
# 3                  6                                8
# 4                  4                                1
#
#    uniformidad_de_forma_de_celda  adherencia_marginal  \
# 0                              1                    1
# 1                              4                    5
# 2                              1                    1
# 3                              8                    1
# 4                              1                    3
#
#    tamano_de_una_celula_epitelial  nucleos_desnudos  cromatina_blanda  \
# 0                               2                 1                 3
# 1                               7                10                 3
# 2                               2                 2                 3
# ...

# %% [markdown]
# ### Estructura de los datos

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 10 columns):
# espesor_del_grupo                  569 non-null int64
# uniformidad_del_tamano_de_celda    569 non-null int64
# uniformidad_de_forma_de_celda      569 non-null int64
# adherencia_marginal                569 non-null int64
# tamano_de_una_celula_epitelial     569 non-null int64
# nucleos_desnudos                   569 non-null int64
# cromatina_blanda                   569 non-null int64
# nucleolos_normales                 569 non-null int64
# mitosis                            569 non-null int64
# clase                              569 non-null int64
# dtypes: int64(10)
# memory usage: 44.5 KB

# %% [markdown]
# # Interpretacion de datos

# %% [markdown]
# ### Interpretacion por categoria

# %%
plt.figure(figsize=(18,6))
datos[datos['clase']==0]['espesor_del_grupo'].hist(alpha=0.5,color='blue', bins=30, label='Clase = Benigno')
datos[datos['clase']==1]['espesor_del_grupo'].hist(alpha=0.5,color='red', bins=30, label='Clase = Maligno')
plt.legend(fontsize=16),plt.xlabel('Espesor del Grupo', fontsize=18);

# %%
plt.figure(figsize=(18,6))
datos[datos['clase']==0]['uniformidad_del_tamano_de_celda'].hist(alpha=0.5,color='blue', bins=30,label='Clase = Benigno')
datos[datos['clase']==1]['uniformidad_del_tamano_de_celda'].hist(alpha=0.5,color='red', bins=30,label='Clase = Maligno')
plt.legend(fontsize=16), plt.xlabel('Uniformidad del Tamaño de la Célula', fontsize=18)
# Out:
# (<matplotlib.legend.Legend at 0x1e6adabab38>,
#  Text(0.5, 0, 'Uniformidad del Tamaño de la Célula'))

# %%
plt.figure(figsize=(18,6))
datos[datos['clase']==0]['uniformidad_de_forma_de_celda'].hist(alpha=0.5,color='blue', bins=30, label='Clase = Benigno')
datos[datos['clase']==1]['uniformidad_de_forma_de_celda'].hist(alpha=0.5,color='red', bins=30, label='Clase = Maligno')
plt.legend(fontsize=16), plt.xlabel('Uniformidad de la Forma de la Célula', fontsize=18);

# %%
plt.figure(figsize=(18,6))
datos[datos['clase']==0]['adherencia_marginal'].hist(alpha=0.5,color='blue', bins=30, label='Clase = Benigno')
datos[datos['clase']==1]['adherencia_marginal'].hist(alpha=0.5,color='red', bins=30, label='Clase = Maligno')
plt.legend(fontsize=16), plt.xlabel('Adherencia Marginal', fontsize=18);

# %%
plt.figure(figsize=(18,6))
datos[datos['clase']==0]['tamano_de_una_celula_epitelial'].hist(alpha=0.5,color='blue', bins=30, label='Clase = Benigno')
datos[datos['clase']==1]['tamano_de_una_celula_epitelial'].hist(alpha=0.5,color='red', bins=30, label='Clase = Maligno')
plt.legend(fontsize=16), plt.xlabel('Tamaño de una Celula Epitelial', fontsize=18);

# %%
plt.figure(figsize=(18,6))
datos[datos['clase']==0]['nucleos_desnudos'].hist(alpha=0.5,color='blue', bins=30, label='Clase = Benigno')
datos[datos['clase']==1]['nucleos_desnudos'].hist(alpha=0.5,color='red', bins=30, label='Clase = Maligno')
plt.legend(fontsize=16), plt.xlabel('Nucleos Desnudos', fontsize=18);

# %%
plt.figure(figsize=(18,6))
datos[datos['clase']==0]['cromatina_blanda'].hist(alpha=0.5,color='blue', bins=30, label='Clase = Benigno')
datos[datos['clase']==1]['cromatina_blanda'].hist(alpha=0.5,color='red', bins=30, label='Clase = Maligno')
plt.legend(fontsize=16), plt.xlabel('Cromatina Blanda', fontsize=18);

# %%
plt.figure(figsize=(18,6))
datos[datos['clase']==0]['nucleolos_normales'].hist(alpha=0.5,color='blue', bins=30, label='Clase = Benigno')
datos[datos['clase']==1]['nucleolos_normales'].hist(alpha=0.5,color='red', bins=30, label='Clase = Maligno')
plt.legend(fontsize=16), plt.xlabel('Nucleolos Normales', fontsize=18);

# %%
plt.figure(figsize=(18,6))
datos[datos['clase']==0]['mitosis'].hist(alpha=0.5,color='blue', bins=30, label='Clase = Benigno')
datos[datos['clase']==1]['mitosis'].hist(alpha=0.5,color='red', bins=30, label='Clase = Maligno')
plt.legend(fontsize=16), plt.xlabel('Mitosis', fontsize=18);

# %% [markdown]
# ### Interpretacion de relaciones

# %%
import seaborn as sns

# %%
plt.figure(figsize=(18, 18))
sns.set(font_scale=1.5)
sns.heatmap(datos.corr(), annot=True, linewidths=.5)

# %% [markdown]
# # Interpretacion

# %% [markdown]
# De la visualizacion de los graficos por categoria y el grafico de relaciones, podemos entender que la categoria, o variable, NUCLEOLOS DESNUDOS (BARE NUCLEOLI) no nos aporta mucha informacion para la prediccion de una respuesta, por lo que dependera del desarrollador si presindir o no de esta informacion u otra que considere importante.

# %% [markdown]
# A su vez, en el primer algoritmo (Regresion Logistica) se implementara esta diferencia con el fin de comparar los cambios que genere.
